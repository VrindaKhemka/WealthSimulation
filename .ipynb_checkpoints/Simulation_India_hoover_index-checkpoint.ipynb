# %%
import random
import matplotlib.pyplot as plt
import numpy as np

class Agent:

    def __init__(self):
        self.money = 0
        self.class_type = 'middle'

    def consume(self, seller, amount):
          self.money -= amount
          seller.money += amount

# %%
class Simulation:
    def __init__(self, num_agents, num_time_steps):
        self.num_agents = num_agents
        self.num_time_steps = num_time_steps
        self.agents = [Agent() for _ in range(num_agents)]
        self.total_tax = 0
        self.update_thresholds()
        self.update_wealth()
        self.segregate_agents()

        # Lists to track wealth and class of specific agents
        self.rich_agent_wealth = []
        self.middle_agent_wealth = []
        self.poor_agent_wealth = []
        self.rich_agent_classes = []
        self.middle_agent_classes = []
        self.poor_agent_classes = []

    def update_wealth(self):
        # Generate random wealth values based on specified percentages
        wealth_values = [random.uniform(0.1, 5) for _ in range(int(0.7 * self.num_agents))] + [random.uniform(5, 15) for _ in range(int(0.25 * self.num_agents))] + [random.uniform(15, 200) for _ in range(int(0.05 * self.num_agents))]        
        random.shuffle(wealth_values)

        # Update agent wealth values
        for i, agent in enumerate(self.agents):
            agent.money = wealth_values[i]


    def calculate_tax(self, wealth):
        scaled_slab_1 = 3
        scaled_slab_2 = 6
        scaled_slab_3 = 9
        scaled_slab_4 = 12
        scaled_slab_5 = 15

        if wealth <= scaled_slab_1:
            return 0
        elif wealth <= scaled_slab_2:
            return 0.05 * (wealth - scaled_slab_1)
        elif wealth <= scaled_slab_3:
            return 0.1 * (wealth - scaled_slab_2) + 0.05 * (scaled_slab_2 - scaled_slab_1)
        elif wealth <= scaled_slab_4:
            return 0.15 * (wealth - scaled_slab_3) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2)
        elif wealth <= scaled_slab_5:
            return 0.2 * (wealth - scaled_slab_4) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2) + 0.15 * (scaled_slab_4 - scaled_slab_3)
        else:
            return 0.3 * (wealth - scaled_slab_5) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2) + 0.15 * (scaled_slab_4 - scaled_slab_3) + 0.2 * (scaled_slab_5 - scaled_slab_4)

    def update_agents(self):
      # Select two random agents
      random_indices = random.sample(range(self.num_agents), 2)
      agent1, agent2 = self.agents[random_indices[0]], self.agents[random_indices[1]]

      # Base trade probability
      trade_probab = 0.1 # Lower base probability to reduce fluctuations

      # Increase probability if agents are from the same class
      if agent1.class_type == agent2.class_type:
          trade_probab = 0.25

      # Modify probability based on the class interaction
      if (agent1.class_type == 'rich' and agent2.class_type == 'poor') or (agent2.class_type == 'rich' and agent1.class_type == 'poor'):
          trade_probab *= 0.75 # Decrease probability for rich-poor trades to reduce significant disruptions
      if(agent1.class_type =='rich') or (agent2.class_type=='poor'):
        trade_probab*=0.5
      if(agent2.class_type == 'rich'):
        trade_probab*=1.75

      if random.random() < trade_probab:
          # Transaction amount is a smaller fraction of the lesser wealth to minimize disruption
          transaction_amount = 0.075 * (agent1.money * agent2.money) / (agent1.money + agent2.money)
          agent1.consume(agent2, transaction_amount)


    def deduct_tax(self):
        for agent in self.agents:
            tax = self.calculate_tax(agent.money)
            agent.money -= tax
            self.total_tax += tax

    def redist(self):
        add_val = self.total_tax / self.num_agents
        for agent in self.agents:
            agent.money += add_val
        self.total_tax = 0

    def update_thresholds(self):
        wealths = [agent.money for agent in self.agents]
        sorted_wealths = np.sort(wealths)

        self.lower_threshold = np.percentile(sorted_wealths, 50)  # 50th percentile
        self.upper_threshold = np.percentile(sorted_wealths, 90)  # 90th percentile

    def segregate_agents(self):
        for agent in self.agents:
            if agent.money <= self.lower_threshold:
                agent.class_type = 'poor'
            elif agent.money >= self.upper_threshold:
                agent.class_type = 'rich'
            else:
                agent.class_type = 'middle'

    def select_and_track_agents(self):
        random.shuffle(self.agents)
        for agent in self.agents:
            if agent.class_type == 'rich':
                self.rich_agent = agent
                break

        for agent in self.agents:
            if agent.class_type == 'middle':
                self.middle_agent = agent
                break

        for agent in self.agents:
            if agent.class_type == 'poor':
                self.poor_agent = agent
                break

        self.rich_agent_wealth.append(self.rich_agent.money)
        self.middle_agent_wealth.append(self.middle_agent.money)
        self.poor_agent_wealth.append(self.poor_agent.money)

        self.rich_agent_classes.append(self.rich_agent.class_type)
        self.middle_agent_classes.append(self.middle_agent.class_type)
        self.poor_agent_classes.append(self.poor_agent.class_type)

    def record_agent_classes(self):
        self.rich_agent_classes.append(self.rich_agent.class_type)
        self.middle_agent_classes.append(self.middle_agent.class_type)
        self.poor_agent_classes.append(self.poor_agent.class_type)

    def run_simulation(self):
        for _ in range(self.num_time_steps):
            self.update_agents()
        self.deduct_tax()
        self.redist()

# %%
def gini_coefficient(wealths):
    n = len(wealths)
    if n == 0:
        return 0

    # Step 1: Sort the wealth list
    sorted_wealths = np.sort(wealths)

    # Step 2: Calculate the mean absolute difference
    diff_matrix = np.abs(sorted_wealths[:, None] - sorted_wealths)
    mean_abs_diff = np.mean(diff_matrix)

    # Step 3: Compute the mean wealth
    mean_wealth = np.mean(sorted_wealths)

    # Step 4: Compute the Gini coefficient
    gini_index = mean_abs_diff / (2 * mean_wealth)
    return gini_index

# %%
def hoover_index(wealths):
    n = len(wealths)
    if n == 0:
        return 0
    sorted_wealths = np.sort(wealths)
    mean_wealth = np.mean(sorted_wealths)
    sum_diff = np.sum(np.abs(sorted_wealths - mean_wealth))
    hoover_index = sum_diff / (2 * n * mean_wealth)
    return hoover_index

# %%
# Simulation parameters
num_agents = 1000
num_time_steps = 100000
gini_indices= []
hoover_indices = []
# Initialize the simulation
sim = Simulation(num_agents, num_time_steps)

# Run simulation for a total of 500 iterations, segregating after each redistribution
for i in range(50):
    sim.run_simulation()
    if i % 25 == 0:  # Update thresholds every 50 iterations
        sim.update_thresholds()
    sim.segregate_agents()
    if i == 1:  # Select agents to track after initial segregation
        sim.select_and_track_agents()
    elif i>1:
        # Record wealth and class of the tracked agents
        sim.rich_agent_wealth.append(sim.rich_agent.money)
        sim.middle_agent_wealth.append(sim.middle_agent.money)
        sim.poor_agent_wealth.append(sim.poor_agent.money)

        sim.record_agent_classes()
    current_wealths = [agent.money for agent in sim.agents]
    gini_index = gini_coefficient(current_wealths)
    gini_indices.append(gini_index)

    hoover_index_val = hoover_index(current_wealths)
    hoover_indices.append(hoover_index_val)


    print(f"Iteration {i + 1} complete, Gini Index: {gini_index}, Hoover Index: {hoover_index_val}")

# Plot the wealth of the tracked agents
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(sim.rich_agent_wealth, label='Rich Agent')
plt.plot(sim.middle_agent_wealth, label='Middle Agent')
plt.plot(sim.poor_agent_wealth, label='Poor Agent')
plt.xlabel('Iteration')
plt.ylabel('Wealth')
plt.legend()

# Plot the Gini coefficient over iterations
plt.subplot(1, 2, 2)
plt.plot(gini_indices, label='Gini Index', color='blue')
plt.plot(hoover_indices, label='Hoover Index', color='red')
plt.title('Income Inequality Over Time')
plt.xlabel('Iteration')
plt.ylabel('Index Value')
plt.legend()
plt.grid(True)
plt.show()

# Analyze class changes
def analyze_class_changes(agent_classes, agent_label):
    changes = 0
    for i in range(1, len(agent_classes)):
        if agent_classes[i] != agent_classes[i - 1]:
            changes += 1
    print(f"{agent_label} changed class {changes} times.")

analyze_class_changes(sim.rich_agent_classes, "Rich Agent")
analyze_class_changes(sim.middle_agent_classes, "Middle Agent")
analyze_class_changes(sim.poor_agent_classes, "Poor Agent")
# Out:
# Iteration 1 complete, Gini Index: 0.5564539143165828, Hoover Index: 0.4192256312905389
# Iteration 2 complete, Gini Index: 0.470332660131422, Hoover Index: 0.3477566477355168
# Iteration 3 complete, Gini Index: 0.4171275518091164, Hoover Index: 0.30498085232715116
# Iteration 4 complete, Gini Index: 0.38531738394890874, Hoover Index: 0.27990054113295654
# Iteration 5 complete, Gini Index: 0.36549374253127126, Hoover Index: 0.2651048051265947
# Iteration 6 complete, Gini Index: 0.34968822687294665, Hoover Index: 0.2542260208925887
# Iteration 7 complete, Gini Index: 0.34455989202477, Hoover Index: 0.2521195124105686
# Iteration 8 complete, Gini Index: 0.34280257720045354, Hoover Index: 0.2524192273523844
# Iteration 9 complete, Gini Index: 0.3442489501012851, Hoover Index: 0.2562414710342522
# Iteration 10 complete, Gini Index: 0.3455061923180075, Hoover Index: 0.2571604076948507
# Iteration 11 complete, Gini Index: 0.35020991058105133, Hoover Index: 0.26450757035538325
# Iteration 12 complete, Gini Index: 0.34949585807191585, Hoover Index: 0.2645503557994758
# Iteration 13 complete, Gini Index: 0.3512287349931314, Hoover Index: 0.265906940901758
# Iteration 14 complete, Gini Index: 0.3487631192928226, Hoover Index: 0.26445780520926915
# Iteration 15 complete, Gini Index: 0.3526177859769459, Hoover Index: 0.26722730943394013
# Iteration 16 complete, Gini Index: 0.3518994239469743, Hoover Index: 0.2670916320285043
# Iteration 17 complete, Gini Index: 0.35506230655820675, Hoover Index: 0.27250930765791925
# Iteration 18 complete, Gini Index: 0.35410994319876987, Hoover Index: 0.2727196922923338
# Iteration 19 complete, Gini Index: 0.35436911844575886, Hoover Index: 0.27386624190438
# Iteration 20 complete, Gini Index: 0.3558314616889068, Hoover Index: 0.27453345840609844
# Iteration 21 complete, Gini Index: 0.35690024942832055, Hoover Index: 0.27645360333311786
# Iteration 22 complete, Gini Index: 0.35718328464657645, Hoover Index: 0.27595796886178114
# Iteration 23 complete, Gini Index: 0.355793122209534, Hoover Index: 0.2771161744634295
# Iteration 24 complete, Gini Index: 0.35545915654709165, Hoover Index: 0.27790629820565116
# Iteration 25 complete, Gini Index: 0.3553898804697304, Hoover Index: 0.27763076895821603
# Iteration 26 complete, Gini Index: 0.3552598932052577, Hoover Index: 0.2782596596147337
# Iteration 27 complete, Gini Index: 0.33983856736966483, Hoover Index: 0.2610014762533253
# Iteration 28 complete, Gini Index: 0.330729909553962, Hoover Index: 0.2505859943531615
# Iteration 29 complete, Gini Index: 0.3241344905783109, Hoover Index: 0.24425142453782087
# Iteration 30 complete, Gini Index: 0.31773333980514973, Hoover Index: 0.23900860695380152
# Iteration 31 complete, Gini Index: 0.31160838850846057, Hoover Index: 0.23273079451995
# Iteration 32 complete, Gini Index: 0.310978748596969, Hoover Index: 0.2298649556444994
# Iteration 33 complete, Gini Index: 0.3091165155184958, Hoover Index: 0.22769004696758177
# Iteration 34 complete, Gini Index: 0.3090454740704265, Hoover Index: 0.22677568607487533
# Iteration 35 complete, Gini Index: 0.3087021900569552, Hoover Index: 0.22707821725876012
# Iteration 36 complete, Gini Index: 0.30329331019238825, Hoover Index: 0.22273266761628177
# Iteration 37 complete, Gini Index: 0.30199058080828883, Hoover Index: 0.2204802818612707
# Iteration 38 complete, Gini Index: 0.3044448677122926, Hoover Index: 0.2227636102962804
# Iteration 39 complete, Gini Index: 0.3032373832972663, Hoover Index: 0.2216898741871387
# Iteration 40 complete, Gini Index: 0.3005839493157202, Hoover Index: 0.22036743823926935
# Iteration 41 complete, Gini Index: 0.3013255650327751, Hoover Index: 0.22146691020943626
# Iteration 42 complete, Gini Index: 0.30169986669095866, Hoover Index: 0.22174882845241753
# Iteration 43 complete, Gini Index: 0.30371755960541097, Hoover Index: 0.22362044526558683
# Iteration 44 complete, Gini Index: 0.30319082127263025, Hoover Index: 0.22314604825907008
# Iteration 45 complete, Gini Index: 0.3024900783436908, Hoover Index: 0.22209613446602317
# Iteration 46 complete, Gini Index: 0.30223774832916483, Hoover Index: 0.22175329653841244
# Iteration 47 complete, Gini Index: 0.30600184429266336, Hoover Index: 0.22614651574976846
# Iteration 48 complete, Gini Index: 0.3056826508215066, Hoover Index: 0.2251618467689345
# Iteration 49 complete, Gini Index: 0.30672046741593884, Hoover Index: 0.22668775182434514
# Iteration 50 complete, Gini Index: 0.30736576248800584, Hoover Index: 0.22633712015543805
# Rich Agent changed class 1 times.
# Middle Agent changed class 1 times.
# Poor Agent changed class 6 times.

# %%
wealths = [agent.money for agent in sim.agents]
plt.hist(wealths, bins=50, edgecolor='black')
plt.xlabel('Wealth')
plt.ylabel('Number of Agents')
plt.title('Wealth Distribution at End of Simulation')
plt.show()

# %%
# Plot the wealth of the tracked agents
plt.plot(sim.rich_agent_wealth, label='Rich Agent')
# plt.plot(sim.middle_agent_wealth, label='Middle Agent')
plt.plot(sim.poor_agent_wealth, label='Poor Agent')
plt.xlabel('Iteration')
plt.ylabel('Wealth')
plt.legend()
plt.show()

# %%
# import seaborn as sns
# plt.style.use("bmh")
# sns.kdeplot(flattened_wealth_distributions, bw_adjust=0.5, fill=True, alpha=0.6)

# # Set titles and labels
# plt.title("Wealth Distribution", size=17, pad=10)
# plt.xlabel("Wealth")
# plt.ylabel("Density")
# plt.grid(False)

# # Set x-ticks
# plt.xticks(range(0, int(max(flattened_wealth_distributions)) + 100, 500))

# # Show the plot
# plt.show()

# %%
np.mean(gini_indices)
# Out:
# 0.34177973154962293

# %%
gini_indices[-1]
# Out:
# 0.3049172612098177

# %%
np.mean(hoover_indices)
# Out:
# 0.2590837389471398

# %%
hoover_indices[-1]
# Out:
# 0.22569157619138128
