# %%
import random
import matplotlib.pyplot as plt
import numpy as np

class Agent:

    def __init__(self):
        self.money = 0
        self.class_type = 'middle'

    def consume(self, seller, amount):
          self.money -= amount
          seller.money += amount

# %%
class Simulation:
    def __init__(self, num_agents, num_time_steps):
        self.num_agents = num_agents
        self.num_time_steps = num_time_steps
        self.agents = [Agent() for _ in range(num_agents)]
        self.total_tax = 0
        self.update_thresholds()
        self.update_wealth()
        self.segregate_agents()

        # Lists to track wealth and class of specific agents
        self.rich_agent_wealth = []
        self.middle_agent_wealth = []
        self.poor_agent_wealth = []
        self.rich_agent_classes = []
        self.middle_agent_classes = []
        self.poor_agent_classes = []

    def update_wealth(self):
        # Generate random wealth values based on specified percentages
        wealth_values = [random.uniform(0.1, 3) for _ in range(int(0.5 * self.num_agents))] + [random.uniform(3, 12) for _ in range(int(0.4 * self.num_agents))] + [random.uniform(12, 50) for _ in range(int(0.1 * self.num_agents))]
        random.shuffle(wealth_values)

        # Update agent wealth values
        for i, agent in enumerate(self.agents):
            agent.money = wealth_values[i]


    def calculate_tax(self, wealth):
        scaled_slab_1 = 3
        scaled_slab_2 = 6
        scaled_slab_3 = 9
        scaled_slab_4 = 12
        scaled_slab_5 = 15

        if wealth <= scaled_slab_1:
            return 0
        elif wealth <= scaled_slab_2:
            return 0.05 * (wealth - scaled_slab_1)
        elif wealth <= scaled_slab_3:
            return 0.1 * (wealth - scaled_slab_2) + 0.05 * (scaled_slab_2 - scaled_slab_1)
        elif wealth <= scaled_slab_4:
            return 0.15 * (wealth - scaled_slab_3) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2)
        elif wealth <= scaled_slab_5:
            return 0.2 * (wealth - scaled_slab_4) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2) + 0.15 * (scaled_slab_4 - scaled_slab_3)
        else:
            return 0.3 * (wealth - scaled_slab_5) + 0.05 * (scaled_slab_2 - scaled_slab_1) + 0.1 * (scaled_slab_3 - scaled_slab_2) + 0.15 * (scaled_slab_4 - scaled_slab_3) + 0.2 * (scaled_slab_5 - scaled_slab_4)

    def update_agents(self):
      # Select two random agents
      random_indices = random.sample(range(self.num_agents), 2)
      agent1, agent2 = self.agents[random_indices[0]], self.agents[random_indices[1]]

      # Base trade probability
      trade_probab = 0.1 # Lower base probability to reduce fluctuations

      # Increase probability if agents are from the same class
      if agent1.class_type == agent2.class_type:
          trade_probab = 0.25

      # Modify probability based on the class interaction
      if (agent1.class_type == 'rich' and agent2.class_type == 'poor') or (agent2.class_type == 'rich' and agent1.class_type == 'poor'):
          trade_probab *= 0.75 # Decrease probability for rich-poor trades to reduce significant disruptions
      if(agent1.class_type =='rich') or (agent2.class_type=='poor'):
        trade_probab*=0.5
      if(agent2.class_type == 'rich'):
        trade_probab*=1.75

      if random.random() < trade_probab:
          # Transaction amount is a smaller fraction of the lesser wealth to minimize disruption
          transaction_amount = 0.075 * (agent1.money * agent2.money) / (agent1.money + agent2.money)
          agent1.consume(agent2, transaction_amount)


    def deduct_tax(self):
        for agent in self.agents:
            tax = self.calculate_tax(agent.money)
            agent.money -= tax
            self.total_tax += tax

    def redist(self):
        add_val = self.total_tax / self.num_agents
        for agent in self.agents:
            agent.money += add_val
        self.total_tax = 0

    def update_thresholds(self):
        wealths = [agent.money for agent in self.agents]
        sorted_wealths = np.sort(wealths)

        self.lower_threshold = np.percentile(sorted_wealths, 50)  # 50th percentile
        self.upper_threshold = np.percentile(sorted_wealths, 90)  # 90th percentile

    def segregate_agents(self):
        for agent in self.agents:
            if agent.money <= self.lower_threshold:
                agent.class_type = 'poor'
            elif agent.money >= self.upper_threshold:
                agent.class_type = 'rich'
            else:
                agent.class_type = 'middle'

    def select_and_track_agents(self):
        random.shuffle(self.agents)
        for agent in self.agents:
            if agent.class_type == 'rich':
                self.rich_agent = agent
                break

        for agent in self.agents:
            if agent.class_type == 'middle':
                self.middle_agent = agent
                break

        for agent in self.agents:
            if agent.class_type == 'poor':
                self.poor_agent = agent
                break

        self.rich_agent_wealth.append(self.rich_agent.money)
        self.middle_agent_wealth.append(self.middle_agent.money)
        self.poor_agent_wealth.append(self.poor_agent.money)

        self.rich_agent_classes.append(self.rich_agent.class_type)
        self.middle_agent_classes.append(self.middle_agent.class_type)
        self.poor_agent_classes.append(self.poor_agent.class_type)

    def record_agent_classes(self):
        self.rich_agent_classes.append(self.rich_agent.class_type)
        self.middle_agent_classes.append(self.middle_agent.class_type)
        self.poor_agent_classes.append(self.poor_agent.class_type)

    def run_simulation(self):
        for _ in range(self.num_time_steps):
            self.update_agents()
        self.deduct_tax()
        self.redist()

# %%
def gini_coefficient(wealths):
    n = len(wealths)
    if n == 0:
        return 0

    # Step 1: Sort the wealth list
    sorted_wealths = np.sort(wealths)

    # Step 2: Calculate the mean absolute difference
    diff_matrix = np.abs(sorted_wealths[:, None] - sorted_wealths)
    mean_abs_diff = np.mean(diff_matrix)

    # Step 3: Compute the mean wealth
    mean_wealth = np.mean(sorted_wealths)

    # Step 4: Compute the Gini coefficient
    gini_index = mean_abs_diff / (2 * mean_wealth)
    return gini_index

# %%
def hoover_index(wealths):
    n = len(wealths)
    if n == 0:
        return 0
    sorted_wealths = np.sort(wealths)
    mean_wealth = np.mean(sorted_wealths)
    sum_diff = np.sum(np.abs(sorted_wealths - mean_wealth))
    hoover_index = sum_diff / (2 * n * mean_wealth)
    return hoover_index

# %%
# Simulation parameters
num_agents = 1000
num_time_steps = 100000
gini_indices= []
hoover_indices = []
# Initialize the simulation
sim = Simulation(num_agents, num_time_steps)

# Run simulation for a total of 500 iterations, segregating after each redistribution
for i in range(100):
    sim.run_simulation()
    if i % 50 == 0:  # Update thresholds every 50 iterations
        sim.update_thresholds()
    sim.segregate_agents()
    if i == 1:  # Select agents to track after initial segregation
        sim.select_and_track_agents()
    elif i>1:
        # Record wealth and class of the tracked agents
        sim.rich_agent_wealth.append(sim.rich_agent.money)
        sim.middle_agent_wealth.append(sim.middle_agent.money)
        sim.poor_agent_wealth.append(sim.poor_agent.money)

        sim.record_agent_classes()
    current_wealths = [agent.money for agent in sim.agents]
    gini_index = gini_coefficient(current_wealths)
    gini_indices.append(gini_index)

    hoover_index_val = hoover_index(current_wealths)
    hoover_indices.append(hoover_index_val)


    print(f"Iteration {i + 1} complete, Gini Index: {gini_index}, Hoover Index: {hoover_index_val}")

# Plot the wealth of the tracked agents
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(sim.rich_agent_wealth, label='Rich Agent')
plt.plot(sim.middle_agent_wealth, label='Middle Agent')
plt.plot(sim.poor_agent_wealth, label='Poor Agent')
plt.xlabel('Iteration')
plt.ylabel('Wealth')
plt.legend()

# Plot the Gini coefficient over iterations
plt.subplot(1, 2, 2)
plt.plot(gini_indices, label='Gini Index', color='blue')
plt.plot(hoover_indices, label='Hoover Index', color='red')
plt.title('Income Inequality Over Time')
plt.xlabel('Iteration')
plt.ylabel('Index Value')
plt.legend()
plt.grid(True)
plt.show()

# Analyze class changes
def analyze_class_changes(agent_classes, agent_label):
    changes = 0
    for i in range(1, len(agent_classes)):
        if agent_classes[i] != agent_classes[i - 1]:
            changes += 1
    print(f"{agent_label} changed class {changes} times.")

analyze_class_changes(sim.rich_agent_classes, "Rich Agent")
analyze_class_changes(sim.middle_agent_classes, "Middle Agent")
analyze_class_changes(sim.poor_agent_classes, "Poor Agent")
# Out:
# Iteration 1 complete, Gini Index: 0.4946985138574155, Hoover Index: 0.3663674848290002
# Iteration 2 complete, Gini Index: 0.4558017281982981, Hoover Index: 0.3396568091424926
# Iteration 3 complete, Gini Index: 0.43080221107950506, Hoover Index: 0.3211043919577212
# Iteration 4 complete, Gini Index: 0.41510439668923704, Hoover Index: 0.30956143283108234
# Iteration 5 complete, Gini Index: 0.4046873921553819, Hoover Index: 0.3021310489857709
# Iteration 6 complete, Gini Index: 0.3975443672005142, Hoover Index: 0.29523317551562067
# Iteration 7 complete, Gini Index: 0.3930350961312243, Hoover Index: 0.2929428002454892
# Iteration 8 complete, Gini Index: 0.394226622896284, Hoover Index: 0.29412566380025956
# Iteration 9 complete, Gini Index: 0.3922897359655625, Hoover Index: 0.2926441724993079
# Iteration 10 complete, Gini Index: 0.38998422808722705, Hoover Index: 0.2903696335185554
# Iteration 11 complete, Gini Index: 0.3903442675768363, Hoover Index: 0.2914650316975693
# Iteration 12 complete, Gini Index: 0.38925998883334273, Hoover Index: 0.2902700431296855
# Iteration 13 complete, Gini Index: 0.38807334244843505, Hoover Index: 0.2871170058544005
# Iteration 14 complete, Gini Index: 0.38995615701313463, Hoover Index: 0.2874517734509854
# Iteration 15 complete, Gini Index: 0.38854146089616254, Hoover Index: 0.28589283308780156
# Iteration 16 complete, Gini Index: 0.38803342758018294, Hoover Index: 0.2870798358556848
# Iteration 17 complete, Gini Index: 0.3908355330183458, Hoover Index: 0.28936186626643434
# Iteration 18 complete, Gini Index: 0.3917778792501086, Hoover Index: 0.2902576373220656
# Iteration 19 complete, Gini Index: 0.38922589535883156, Hoover Index: 0.28918138250798187
# Iteration 20 complete, Gini Index: 0.38877559246316706, Hoover Index: 0.2897717546804916
# Iteration 21 complete, Gini Index: 0.3901750522220764, Hoover Index: 0.29162698192947484
# Iteration 22 complete, Gini Index: 0.38768845350442543, Hoover Index: 0.2889548344194164
# Iteration 23 complete, Gini Index: 0.3906811901046219, Hoover Index: 0.29286656437580355
# Iteration 24 complete, Gini Index: 0.39298727949374973, Hoover Index: 0.2950809013920713
# Iteration 25 complete, Gini Index: 0.39242449518030703, Hoover Index: 0.29433613975965467
# Iteration 26 complete, Gini Index: 0.392202798407142, Hoover Index: 0.29453727364883064
# Iteration 27 complete, Gini Index: 0.38907618103711716, Hoover Index: 0.2899959006320025
# Iteration 28 complete, Gini Index: 0.38901312564463175, Hoover Index: 0.28905616327370914
# Iteration 29 complete, Gini Index: 0.3894721831021358, Hoover Index: 0.2905634790393768
# Iteration 30 complete, Gini Index: 0.3887985716647354, Hoover Index: 0.28887117928393247
# Iteration 31 complete, Gini Index: 0.38812742423781293, Hoover Index: 0.28936811282986985
# Iteration 32 complete, Gini Index: 0.3878015486301351, Hoover Index: 0.2880209485795981
# Iteration 33 complete, Gini Index: 0.38826413672332966, Hoover Index: 0.28816590846847145
# Iteration 34 complete, Gini Index: 0.3888315732113847, Hoover Index: 0.2887698434548624
# Iteration 35 complete, Gini Index: 0.3901522605710701, Hoover Index: 0.28977032331461183
# Iteration 36 complete, Gini Index: 0.3896957336571657, Hoover Index: 0.2916384585084497
# Iteration 37 complete, Gini Index: 0.3884510293619928, Hoover Index: 0.2902617413695899
# Iteration 38 complete, Gini Index: 0.38805877913631825, Hoover Index: 0.2880684722757549
# Iteration 39 complete, Gini Index: 0.38697211573903556, Hoover Index: 0.2873419919365248
# Iteration 40 complete, Gini Index: 0.3867186439285323, Hoover Index: 0.2887463375759212
# Iteration 41 complete, Gini Index: 0.3893974429280918, Hoover Index: 0.29050010455316216
# Iteration 42 complete, Gini Index: 0.3881855800047775, Hoover Index: 0.28948552122326077
# Iteration 43 complete, Gini Index: 0.38695232388329415, Hoover Index: 0.2871297223875618
# Iteration 44 complete, Gini Index: 0.38596204826207536, Hoover Index: 0.2868707574023531
# Iteration 45 complete, Gini Index: 0.38766704860927004, Hoover Index: 0.2881494524076511
# Iteration 46 complete, Gini Index: 0.3878832221133946, Hoover Index: 0.28898744066607274
# Iteration 47 complete, Gini Index: 0.38821495472059975, Hoover Index: 0.28946238246444617
# Iteration 48 complete, Gini Index: 0.38950503494478284, Hoover Index: 0.2924031730953218
# Iteration 49 complete, Gini Index: 0.38984680203549216, Hoover Index: 0.2925164988874256
# Iteration 50 complete, Gini Index: 0.39027625829702145, Hoover Index: 0.29318886464420846
# Iteration 51 complete, Gini Index: 0.39036330752043935, Hoover Index: 0.290695340689819
# Iteration 52 complete, Gini Index: 0.38428886868197637, Hoover Index: 0.2871719201560557
# Iteration 53 complete, Gini Index: 0.3798876798480941, Hoover Index: 0.2844581829180692
# Iteration 54 complete, Gini Index: 0.37904575053787753, Hoover Index: 0.2838531955040948
# Iteration 55 complete, Gini Index: 0.3768088237921498, Hoover Index: 0.283929017530728
# Iteration 56 complete, Gini Index: 0.3741874636582613, Hoover Index: 0.28257845779618473
# Iteration 57 complete, Gini Index: 0.37103826777864235, Hoover Index: 0.2811630856691732
# Iteration 58 complete, Gini Index: 0.3699270632235259, Hoover Index: 0.2805317714476195
# Iteration 59 complete, Gini Index: 0.3676994296109586, Hoover Index: 0.2785735554709037
# Iteration 60 complete, Gini Index: 0.3683271194905943, Hoover Index: 0.27924111434846055
# Iteration 61 complete, Gini Index: 0.36877017943402096, Hoover Index: 0.27984791230792977
# Iteration 62 complete, Gini Index: 0.3659800336712112, Hoover Index: 0.27744085453828476
# Iteration 63 complete, Gini Index: 0.36547008537644543, Hoover Index: 0.27894350118363337
# Iteration 64 complete, Gini Index: 0.3658308420190426, Hoover Index: 0.27879726976303926
# Iteration 65 complete, Gini Index: 0.36638274369453366, Hoover Index: 0.27868206569431525
# Iteration 66 complete, Gini Index: 0.36725059399426063, Hoover Index: 0.2784579544467315
# Iteration 67 complete, Gini Index: 0.36609456926424305, Hoover Index: 0.27844991114129564
# Iteration 68 complete, Gini Index: 0.36831779548676835, Hoover Index: 0.2796335535457061
# Iteration 69 complete, Gini Index: 0.36507340273441224, Hoover Index: 0.2780425289480549
# Iteration 70 complete, Gini Index: 0.3648296079908353, Hoover Index: 0.27568143177137316
# Iteration 71 complete, Gini Index: 0.36534966885116826, Hoover Index: 0.27655908506785637
# Iteration 72 complete, Gini Index: 0.3638954184499837, Hoover Index: 0.27485582859194907
# Iteration 73 complete, Gini Index: 0.3657172414352893, Hoover Index: 0.2756325158342089
# Iteration 74 complete, Gini Index: 0.3650417811696842, Hoover Index: 0.2750579263705904
# Iteration 75 complete, Gini Index: 0.36168296945578465, Hoover Index: 0.27323293786031416
# Iteration 76 complete, Gini Index: 0.36395295243443, Hoover Index: 0.2750576626608271
# Iteration 77 complete, Gini Index: 0.36455101658991146, Hoover Index: 0.2748462233339456
# Iteration 78 complete, Gini Index: 0.3649435013801815, Hoover Index: 0.27497197247790206
# Iteration 79 complete, Gini Index: 0.3671239820329324, Hoover Index: 0.279272560291659
# Iteration 80 complete, Gini Index: 0.36553464962808435, Hoover Index: 0.27869515123773336
# Iteration 81 complete, Gini Index: 0.36581379008026976, Hoover Index: 0.2777315804854627
# Iteration 82 complete, Gini Index: 0.3700323226024694, Hoover Index: 0.2812245164695469
# Iteration 83 complete, Gini Index: 0.3677206658896503, Hoover Index: 0.27950435788747086
# Iteration 84 complete, Gini Index: 0.3652802347291864, Hoover Index: 0.27936477423799033
# Iteration 85 complete, Gini Index: 0.36234965166174016, Hoover Index: 0.2770576980165105
# Iteration 86 complete, Gini Index: 0.3606844473467585, Hoover Index: 0.275138310355419
# Iteration 87 complete, Gini Index: 0.3614863195014539, Hoover Index: 0.27535614264364583
# Iteration 88 complete, Gini Index: 0.36163666692700963, Hoover Index: 0.2748665491570343
# Iteration 89 complete, Gini Index: 0.3579135984032437, Hoover Index: 0.2709811895888612
# Iteration 90 complete, Gini Index: 0.35851457645244167, Hoover Index: 0.27211777289984923
# Iteration 91 complete, Gini Index: 0.36168211126352995, Hoover Index: 0.2746206767916525
# Iteration 92 complete, Gini Index: 0.3644095579652903, Hoover Index: 0.2772313321714781
# Iteration 93 complete, Gini Index: 0.36563522357494443, Hoover Index: 0.2767340736556645
# Iteration 94 complete, Gini Index: 0.3672599467910883, Hoover Index: 0.2802777337786892
# Iteration 95 complete, Gini Index: 0.36327540317995, Hoover Index: 0.27904179948026686
# Iteration 96 complete, Gini Index: 0.3659851294161442, Hoover Index: 0.28089028087277984
# Iteration 97 complete, Gini Index: 0.361975010362512, Hoover Index: 0.2763407561457053
# Iteration 98 complete, Gini Index: 0.3624764661798957, Hoover Index: 0.2770178583786354
# Iteration 99 complete, Gini Index: 0.3604973143438368, Hoover Index: 0.27643203268339167
# Iteration 100 complete, Gini Index: 0.3597203531405103, Hoover Index: 0.27472556244137436
# Rich Agent changed class 2 times.
# Middle Agent changed class 4 times.
# Poor Agent changed class 3 times.

# %%
wealths = [agent.money for agent in sim.agents]
plt.hist(wealths, bins=50, edgecolor='black')
plt.xlabel('Wealth')
plt.ylabel('Number of Agents')
plt.title('Wealth Distribution at End of Simulation')
plt.show()

# %%
# Plot the wealth of the tracked agents
plt.plot(sim.rich_agent_wealth, label='Rich Agent')
# plt.plot(sim.middle_agent_wealth, label='Middle Agent')
plt.plot(sim.poor_agent_wealth, label='Poor Agent')
plt.xlabel('Iteration')
plt.ylabel('Wealth')
plt.legend()
plt.show()

# %%
# import seaborn as sns
# plt.style.use("bmh")
# sns.kdeplot(flattened_wealth_distributions, bw_adjust=0.5, fill=True, alpha=0.6)

# # Set titles and labels
# plt.title("Wealth Distribution", size=17, pad=10)
# plt.xlabel("Wealth")
# plt.ylabel("Density")
# plt.grid(False)

# # Set x-ticks
# plt.xticks(range(0, int(max(flattened_wealth_distributions)) + 100, 500))

# # Show the plot
# plt.show()

# %%
np.mean(gini_indices)
# Out:
# 0.38070196727103395

# %%
gini_indices[-1]
# Out:
# 0.3597203531405103

# %%
np.mean(hoover_indices)
# Out:
# 0.2860773073771768

# %%
hoover_indices[-1]
# Out:
# 0.27472556244137436
